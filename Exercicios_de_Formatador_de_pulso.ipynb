# %%
import numpy as np
import scipy.signal as signal
import matplotlib.pyplot as plt
import random

# %% [markdown]
# # Recriando o código do livro

# %%
#Gerando 1000 simbolos 4 PAM
N = 1000
M = 10 #largura de faixa inicial do pulso
simbolos = np.zeros(N)
for i in range(N):
  simbolos[i] = random.choice([-3,-1,1,3])

# %%
sim_up = np.zeros(N*M)
sim_up[::M] = simbolos #Oversample dos simbolos

pulso = signal.windows.hamming(M) #Pulso com largura de faixa T

out = np.convolve(pulso, sim_up) #Convoluindo o pulso e os simbolos

indices_t = np.arange(4, len(out), M)

figure, axis = plt.subplots(1,2, figsize=(18,5))

# Plotando a saida
axis[0].plot(out)
axis[0].set_xlim([0,250])
axis[0].scatter(indices_t, out[indices_t], color='red', label='Pontos Destacados')
axis[0].set_title('saida do formatador de pulso')
axis[0].set_xlabel('simbolos')
axis[0].grid(True)

# Calculando a resposta em frequência da saida
fft_out = np.fft.fft(out)

# Calculando as frequências correspondentes
freqs = np.fft.fftfreq(len(fft_out))/0.5

# Plotando o espectro de frequência do pulso
axis[1].semilogy(freqs, abs(fft_out))
axis[1].set_title('Espectro da saida do formatador de pulso')
axis[1].set_xlabel('Frequência')
axis[1].set_ylabel('Magnitude')
axis[1].set_xlim([0,1])
axis[1].set_ylim([1e-1,1e4])
axis[1].grid(True)

plt.show()

# %% [markdown]
# # 11.1

# %% [markdown]
# Essa atividade consiste em alterar a largura do pulso

# %%
pulso = signal.windows.hamming(20) #Mesmo pulso, mas com largura dobrada

figure1, axis1 = plt.subplots(1,2, figsize=(18,5))

axis1[0].plot(np.abs(pulso))
axis1[0].set_title('Pulso blip')
axis1[0].set_ylabel('Magnitude')
axis1[0].grid(True)

t, pulso_freqz = signal.freqz(pulso)

pulso_freqz_db = 20 * np.log10(np.abs(pulso_freqz))

# Plotando o espectro de frequência do pulso
axis1[1].semilogy(t/np.pi, abs(pulso_freqz))
axis1[1].set_title('Espectro de Frequência do Pulso blip')
axis1[1].set_xlabel('Frequência normalizada')
axis1[1].set_ylabel('Magnitude')
axis1[1].set_xlim([0,1])
axis1[1].grid(True)

plt.show()

# %%
pulso = signal.windows.hamming(20)

out = np.convolve(pulso, sim_up)

indices_t = np.arange(9, len(out), M)

figure2, axis2 = plt.subplots(1,2, figsize=(18,5))

axis2[0].plot(out)
axis2[0].set_xlim([0,250])
axis2[0].scatter(indices_t, out[indices_t], color='red', label='Pontos Destacados')
plt.grid(True)
axis2[0].grid(True)

fft_out = np.fft.fft(out)

# Calculando as frequências correspondentes
freqs = np.fft.fftfreq(len(fft_out))/0.5

# Plotando o espectro de frequência do pulso
axis2[1].semilogy(freqs, abs(fft_out))
axis2[1].set_title('Espectro de Frequência do Pulso')
axis2[1].set_xlabel('Frequência')
axis2[1].set_ylabel('Magnitude')
axis2[1].set_xlim([0,1])
axis2[1].set_ylim([1e-1,1e4])
axis2[1].grid(True)

plt.show()

# %% [markdown]
# # 11.2

# %% [markdown]
# Para o pulso com largura de faixa 4T, podemos ver que já está impossível de recuperar a mensagem original. Conforme aumento a largura de faixa só piora.

# %%
pulso = signal.windows.hamming(40)

out = np.convolve(pulso, sim_up)

indices_t = np.arange(19, len(out), M)

figure2, axis2 = plt.subplots(1,2, figsize=(18,5))

axis2[0].plot(out)
axis2[0].set_xlim([0,250])
axis2[0].scatter(indices_t, out[indices_t], color='red', label='Pontos Destacados')
plt.grid(True)
axis2[0].grid(True)

fft_out = np.fft.fft(out)

# Calculando as frequências correspondentes
freqs = np.fft.fftfreq(len(fft_out))/0.5

# Plotando o espectro de frequência do pulso
axis2[1].semilogy(freqs, abs(fft_out))
axis2[1].set_title('Espectro de Frequência do Pulso')
axis2[1].set_xlabel('Frequência')
axis2[1].set_ylabel('Magnitude')
axis2[1].set_xlim([0,1])
axis2[1].set_ylim([1e-1,1e4])
axis2[1].grid(True)

plt.show()

# %% [markdown]
# Para o pulso com largura de faixa 6T

# %%
pulso = signal.windows.hamming(60)

out = np.convolve(pulso, sim_up)

indices_t = np.arange(29, len(out), M)

figure2, axis2 = plt.subplots(1,2, figsize=(18,5))

axis2[0].plot(out)
axis2[0].set_xlim([0,250])
axis2[0].scatter(indices_t, out[indices_t], color='red', label='Pontos Destacados')
plt.grid(True)
axis2[0].grid(True)

fft_out = np.fft.fft(out)

# Calculando as frequências correspondentes
freqs = np.fft.fftfreq(len(fft_out))/0.5

# Plotando o espectro de frequência do pulso
axis2[1].semilogy(freqs, abs(fft_out))
axis2[1].set_title('Espectro de Frequência do Pulso')
axis2[1].set_xlabel('Frequência')
axis2[1].set_ylabel('Magnitude')
axis2[1].set_xlim([0,1])
axis2[1].set_ylim([1e-1,1e4])
axis2[1].grid(True)

plt.show()

# %% [markdown]
# Para o pulso com largura de faixa 10T

# %%
pulso = signal.windows.hamming(100)

out = np.convolve(pulso, sim_up)

indices_t = np.arange(49, len(out), M)

figure2, axis2 = plt.subplots(1,2, figsize=(18,5))

axis2[0].plot(out)
axis2[0].set_xlim([0,250])
axis2[0].scatter(indices_t, out[indices_t], color='red', label='Pontos Destacados')
plt.grid(True)
axis2[0].grid(True)

fft_out = np.fft.fft(out)

# Calculando as frequências correspondentes
freqs = np.fft.fftfreq(len(fft_out))/0.5

# Plotando o espectro de frequência do pulso
axis2[1].semilogy(freqs, abs(fft_out))
axis2[1].set_title('Espectro de Frequência do Pulso')
axis2[1].set_xlabel('Frequência')
axis2[1].set_ylabel('Magnitude')
axis2[1].set_xlim([0,1])
axis2[1].set_ylim([1e-1,1e4])
axis2[1].grid(True)

plt.show()

# %% [markdown]
# # 11.14

# %% [markdown]
# Estou plotando o cosseno levantado para cada valor de beta, porém acontece uma inconsistência no seu espectro.

# %%
def cos_l(x,t,b):
  if np.any(x == t/2*b):
    return (np.pi/4*t)*np.sinc(1/2*b)
  elif np.any(x == -t/2*b):
    return (np.pi/4*t)*np.sinc(1/2*b)
  elif b == 0:
    return np.sinc(x/t)/t
  else:
    return (1/t)*(np.sinc(1/t))*(np.cos(np.pi*b*x/t)/(1-(2*b*x/t)**2))

# %%
x_values = np.linspace(-50, 50, 1000)
b = [1, 0.5, 0]
cosseno_levantado1 = cos_l(x_values,10, b[0])
cosseno_levantado2 = cos_l(x_values,10, b[1])
cosseno_levantado3 = cos_l(x_values,10, b[2])

figure1, axis1 = plt.subplots(1,2, figsize=(18,5))

axis1[0].plot(cosseno_levantado1, label = 'beta = 1')
axis1[0].plot(cosseno_levantado2, label = 'beta = 0.5')
axis1[0].plot(cosseno_levantado3, label = 'beta = 0')
axis1[0].set_title('cosseno levantado')
axis1[0].set_ylabel('Magnitude')
axis1[0].grid(True)
axis1[0].legend()

h, pulso_freqz1 = signal.freqz(cosseno_levantado1)
h, pulso_freqz2 = signal.freqz(cosseno_levantado2)
h, pulso_freqz3 = signal.freqz(cosseno_levantado3)
#frequencias = np.fft.fftshift(np.fft.fftfreq(len(cosseno_levantado)))

pulso_freqz_db = 20 * np.log10(np.abs(pulso_freqz))

# Plotando o espectro de frequência do pulso
axis1[1].semilogy(h, abs(pulso_freqz1), label = 'beta = 1')
axis1[1].semilogy(h, abs(pulso_freqz2), label = 'beta = 0.5')
axis1[1].semilogy(h, abs(pulso_freqz3), label = 'beta = 0')
axis1[1].set_title('Espectro do cosseno levantado')
axis1[1].set_xlabel('Frequência')
axis1[1].set_ylabel('Magnitude')
axis1[1].set_xlim([0,1])
axis1[1].legend()
axis1[1].grid(True)

plt.show()
